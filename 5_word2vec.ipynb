# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data


words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000


def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0


def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(
        batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' %
          (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each
    # time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001


with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000
            # batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500
        # steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.027614
# Nearest to or: constituency, wozniak, worshippers, nonsensical, mapping, aegina, schenectady, brazilian,
# Nearest to about: minimal, epidemiology, norm, heteronyms, aru, converting, bem, basie,
# Nearest to i: baltasar, excerpt, heiner, vulgate, independent, condita, gamma, disappeared,
# Nearest to up: sourcebook, padre, counterintelligence, pronouns, looming, dominate, publicity, wrong,
# Nearest to often: martian, herndon, funicular, gamete, zwickau, spectacular, om, deflection,
# Nearest to also: jamming, soaked, beige, climate, overheard, secession, clary, reasonable,
# Nearest to so: forgets, footy, provision, narrowly, honda, novelties, presumed, hk,
# Nearest to is: characterises, bun, diazepam, argentines, teotihuacan, lavish, capitalisation, pakistanis,
# Nearest to war: xxxx, mat, courageous, shed, vestigial, collectives, ground, gabal,
# Nearest to has: repairing, testicles, nationhood, degraded, ousting, segmentata, clubhouse, exploitable,
# Nearest to world: poisoning, postmodernist, luc, expands, persons, riders, gaud, sales,
# Nearest to he: pearls, anglian, asatru, remembers, hollis, noailles, translocation, and,
# Nearest to a: triumphantly, manet, loo, forging, proverb, performer, generate, peregrine,
# Nearest to many: mycenean, estonia, el, repulsive, sticking, allegiance, emanations, crescas,
# Nearest to two: margot, coppersmith, vintage, backed, ageing, blythe, epitomized, wikitravel,
# Nearest to all: alienating, amplified, wore, centralization, mixolydian, soloist, expand, homicidal,
# Average loss at step 2000: 4.370113
# Average loss at step 4000: 3.868047
# Average loss at step 6000: 3.792291
# Average loss at step 8000: 3.687984
# Average loss at step 10000: 3.613803
# Nearest to or: and, kocher, than, backus, spectre, constituency, templars, s,
# Nearest to about: heteronyms, minimal, capricious, mboxx, leuven, copies, pong, epidemiology,
# Nearest to i: mears, gamma, lookahead, physiological, independent, disappeared, heiner, baltasar,
# Nearest to up: lensman, dominate, bothnia, rebadged, counterintelligence, endian, wrong, prism,
# Nearest to often: also, okinawa, herndon, martian, gamete, funicular, generally, that,
# Nearest to also: it, which, often, neurologist, airstrips, cowes, still, then,
# Nearest to so: forgets, thrice, cystic, enact, usually, pluralism, boac, vivant,
# Nearest to is: was, are, has, be, flatted, being, leverett, heritage,
# Nearest to war: alphabet, withstand, revolution, xxxx, scriptores, whore, contorted, dreadnoughts,
# Nearest to has: had, was, have, is, amoeba, tariff, maskhadov, mujahedeen,
# Nearest to world: watterson, postmodernist, billiard, freed, nepalese, peptidoglycan, ero, indictments,
# Nearest to he: it, she, they, soared, currencies, who, excavations, kitchens,
# Nearest to a: the, directly, immediately, its, jedi, stratified, idiomatic, gutenberg,
# Nearest to many: some, sticking, dots, plot, haile, ullmann, mayer, object,
# Nearest to two: three, six, four, five, eight, seven, nine, one,
# Nearest to all: pitch, these, display, alienating, checksum, centralization, copying, pontic,
# Average loss at step 12000: 3.605891
# Average loss at step 14000: 3.580008
# Average loss at step 16000: 3.412554
# Average loss at step 18000: 3.457898
# Average loss at step 20000: 3.543902
# Nearest to or: and, than, vasily, clock, for, fosse, auction, stubbs,
# Nearest to about: leuven, copies, mboxx, norm, bots, that, epidemiology, between,
# Nearest to i: gamma, ii, railhead, puppets, heiner, iii, mears, v,
# Nearest to up: lensman, him, them, carbides, rebadged, althea, keenly, zealots,
# Nearest to often: also, who, generally, okinawa, herndon, martian, avc, gamete,
# Nearest to also: which, often, then, still, neurologist, now, not, carrot,
# Nearest to so: adversaries, healed, nor, outrage, usually, forgets, recount, thrice,
# Nearest to is: was, are, has, be, were, bids, howitzers, chromosome,
# Nearest to war: alphabet, xxxx, withstand, whore, contorted, shed, assailants, mat,
# Nearest to has: had, was, have, is, amoeba, having, sud, halter,
# Nearest to world: willys, billiard, dowling, gting, nepalese, garnier, indictments, colorful,
# Nearest to he: she, it, they, who, there, overviews, currencies, soared,
# Nearest to a: the, this, immediately, another, directly, chlamydia, any, quantifying,
# Nearest to many: some, these, all, several, most, those, other, various,
# Nearest to two: five, three, six, four, seven, eight, one, zero,
# Nearest to all: many, these, several, pitch, display, deprogramming, checksum, expiration,
# Average loss at step 22000: 3.505969
# Average loss at step 24000: 3.488935
# Average loss at step 26000: 3.478388
# Average loss at step 28000: 3.483218
# Average loss at step 30000: 3.504688
# Nearest to or: and, lymphocyte, than, stubbs, perfect, maximal, moldova, underwing,
# Nearest to about: bots, capricious, heteronyms, leopoldo, philippine, between, mboxx, copies,
# Nearest to i: ii, iii, mears, puppets, railhead, gamma, selection, syn,
# Nearest to up: him, lensman, them, carbides, down, rebadged, off, albornoz,
# Nearest to often: generally, also, usually, who, sometimes, still, commonly, widely,
# Nearest to also: often, still, now, which, neurologist, who, it, originally,
# Nearest to so: adversaries, healed, usually, nor, eel, preserved, outrage, foyle,
# Nearest to is: was, has, are, be, became, were, while, had,
# Nearest to war: xxxx, slanted, withstand, shed, nfl, whore, assailants, confound,
# Nearest to has: had, have, is, was, having, cavern, amoeba, halter,
# Nearest to world: billiard, sigmund, indictments, dowling, peptidoglycan, willys, fireball, saliva,
# Nearest to he: she, it, they, who, there, never, overviews, octagon,
# Nearest to a: the, any, another, defiance, no, micros, relinquishing, thackeray,
# Nearest to many: some, several, these, most, those, all, both, various,
# Nearest to two: four, three, five, seven, six, eight, one, zero,
# Nearest to all: these, many, several, some, pontic, pitch, voronin, each,
# Average loss at step 32000: 3.501428
# Average loss at step 34000: 3.492698
# Average loss at step 36000: 3.452989
# Average loss at step 38000: 3.300654
# Average loss at step 40000: 3.432173
# Nearest to or: and, than, outputting, a, without, mill, procter, inductees,
# Nearest to about: between, palatine, philippine, leopoldo, bent, capricious, bots, privatizing,
# Nearest to i: ii, we, you, mears, iii, they, t, selection,
# Nearest to up: him, them, carbides, off, lensman, down, out, zuse,
# Nearest to often: generally, also, usually, sometimes, who, still, commonly, widely,
# Nearest to also: often, now, which, still, usually, originally, who, commonly,
# Nearest to so: healed, foyle, outrage, adversaries, deals, usually, preserved, eel,
# Nearest to is: was, has, are, does, be, if, became, phallic,
# Nearest to war: assailants, gulfs, bien, ragged, xxxx, confound, vita, whore,
# Nearest to has: had, have, was, is, having, amoeba, cavern, farther,
# Nearest to world: billiard, sigmund, serge, pamela, integrate, hurricane, constantin, seaborg,
# Nearest to he: she, it, they, who, there, gunner, never, soared,
# Nearest to a: another, the, any, activating, or, ffg, immediately, this,
# Nearest to many: some, several, these, those, both, most, various, all,
# Nearest to two: four, three, five, six, seven, one, eight, nine,
# Nearest to all: these, several, each, three, many, two, some, both,
# Average loss at step 42000: 3.436383
# Average loss at step 44000: 3.455260
# Average loss at step 46000: 3.452801
# Average loss at step 48000: 3.351108
# Average loss at step 50000: 3.383827
# Nearest to or: and, than, et, straddle, remey, evacuating, anhydrous, scheldt,
# Nearest to about: between, norm, leopoldo, morgenstern, interphase, on, recurrence, palatine,
# Nearest to i: we, ii, you, t, iii, mears, g, regimens,
# Nearest to up: them, him, off, down, out, mendelevium, carbides, back,
# Nearest to often: generally, usually, sometimes, commonly, also, still, widely, now,
# Nearest to also: often, now, which, still, who, originally, initially, actually,
# Nearest to so: then, sachsen, duvall, healed, adversaries, how, forgets, proposing,
# Nearest to is: was, has, are, does, became, remains, although, while,
# Nearest to war: assailants, bien, ragged, hello, gulfs, whore, confound, xxxx,
# Nearest to has: had, have, is, was, having, cavern, farther, amoeba,
# Nearest to world: billiard, sigmund, monaco, gnomes, seaborg, sept, serge, civil,
# Nearest to he: she, it, they, who, there, this, gunner, then,
# Nearest to a: another, any, defiance, the, mandela, relinquishing, no, every,
# Nearest to many: some, several, these, both, those, various, most, fijian,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Nearest to all: these, both, several, each, various, some, many, every,
# Average loss at step 52000: 3.438342
# Average loss at step 54000: 3.431105
# Average loss at step 56000: 3.442012
# Average loss at step 58000: 3.396071
# Average loss at step 60000: 3.395917
# Nearest to or: and, than, musculoskeletal, for, but, outputting, morph, palatable,
# Nearest to about: norm, leopoldo, on, playground, that, heteronyms, tfl, anastasia,
# Nearest to i: you, we, ii, mears, g, t, iii, chants,
# Nearest to up: him, off, them, out, down, back, carbides, mendelevium,
# Nearest to often: usually, generally, sometimes, commonly, also, widely, still, now,
# Nearest to also: now, often, still, which, it, who, originally, actually,
# Nearest to so: then, healed, if, how, nickel, sachsen, adversaries, lunches,
# Nearest to is: was, are, has, be, remains, although, becomes, does,
# Nearest to war: assailants, bien, hello, slanted, confound, battle, gulfs, xxxx,
# Nearest to has: had, have, was, is, having, cavern, berkshire, vanderbilt,
# Nearest to world: billiard, history, indictments, senior, prd, gnomes, tidings, sigmund,
# Nearest to he: she, it, they, who, there, octagon, gunner, currencies,
# Nearest to a: another, the, any, doctrinal, aquifers, relinquishing, micros, flawless,
# Nearest to many: some, several, these, various, both, most, such, all,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to all: some, various, these, both, many, every, several, any,
# Average loss at step 62000: 3.236658
# Average loss at step 64000: 3.256566
# Average loss at step 66000: 3.407469
# Average loss at step 68000: 3.397138
# Average loss at step 70000: 3.360751
# Nearest to or: and, than, but, while, palatable, www, lymphocyte, musculoskeletal,
# Nearest to about: leopoldo, on, that, transposing, between, tfl, bots, philippine,
# Nearest to i: we, you, ii, g, mears, chants, iii, stoiber,
# Nearest to up: them, off, out, him, down, back, carbides, mendelevium,
# Nearest to often: usually, sometimes, commonly, generally, now, widely, also, still,
# Nearest to also: now, still, often, which, originally, never, actually, sometimes,
# Nearest to so: then, if, how, thus, lunches, deals, sachsen, adversaries,
# Nearest to is: was, has, are, be, although, became, remains, does,
# Nearest to war: hello, battle, confound, assailants, slanted, bien, doppelbock, wars,
# Nearest to has: had, have, is, was, having, cavern, contains, since,
# Nearest to world: billiard, u, prd, senior, kinsella, monaco, fyrom, indictments,
# Nearest to he: she, it, they, there, gunner, we, later, who,
# Nearest to a: another, the, aquifers, deontology, enough, any, spores, defiance,
# Nearest to many: some, several, various, these, all, most, both, such,
# Nearest to two: three, four, six, five, one, seven, eight, nine,
# Nearest to all: some, many, various, any, several, both, these, most,
# Average loss at step 72000: 3.371745
# Average loss at step 74000: 3.350572
# Average loss at step 76000: 3.317152
# Average loss at step 78000: 3.353666
# Average loss at step 80000: 3.380522
# Nearest to or: and, while, than, but, like, reciprocated, straddle, callous,
# Nearest to about: frye, leopoldo, cost, between, palatine, nuit, estimated, playground,
# Nearest to i: we, ii, you, iii, g, mears, chants, t,
# Nearest to up: off, out, them, down, him, back, apart, mendelevium,
# Nearest to often: usually, sometimes, commonly, generally, still, typically, now, widely,
# Nearest to also: now, still, often, which, sometimes, never, neurologist, usually,
# Nearest to so: how, sachsen, deals, if, then, lunches, too, healed,
# Nearest to is: was, has, are, although, remains, became, becomes, does,
# Nearest to war: confound, assailants, bien, wars, hello, slanted, doppelbock, gulfs,
# Nearest to has: had, have, is, was, having, although, cavern, but,
# Nearest to world: u, indictments, billiard, senior, kinsella, sigmund, serge, prd,
# Nearest to he: she, it, they, there, who, we, royalists, but,
# Nearest to a: another, the, stricture, defiance, every, any, aquifers, counterproductive,
# Nearest to many: some, several, various, these, numerous, both, all, most,
# Nearest to two: three, six, four, five, seven, eight, one, nine,
# Nearest to all: various, several, any, both, many, some, every, each,
# Average loss at step 82000: 3.403967
# Average loss at step 84000: 3.411951
# Average loss at step 86000: 3.391612
# Average loss at step 88000: 3.351332
# Average loss at step 90000: 3.364639
# Nearest to or: and, including, than, musculoskeletal, elysium, while, directv, straddle,
# Nearest to about: regarding, leopoldo, frye, philippine, jeet, on, nuit, valdemar,
# Nearest to i: we, you, ii, iii, g, v, napo, bosons,
# Nearest to up: off, out, down, them, back, him, apart, mendelevium,
# Nearest to often: commonly, sometimes, usually, generally, still, also, now, typically,
# Nearest to also: now, often, still, sometimes, which, never, actually, neurologist,
# Nearest to so: say, sachsen, how, thus, suggests, too, if, racially,
# Nearest to is: was, has, are, although, refers, be, seems, does,
# Nearest to war: wars, assailants, confound, hello, bien, during, slanted, battle,
# Nearest to has: had, have, is, having, was, requires, since, although,
# Nearest to world: serge, senior, sigmund, direction, billiard, introduced, peptidoglycan, accretion,
# Nearest to he: she, it, they, there, later, who, but, never,
# Nearest to a: another, the, vp, any, every, aquifers, tyrell, counterproductive,
# Nearest to many: several, some, various, these, all, numerous, most, those,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to all: many, several, various, these, any, both, every, each,
# Average loss at step 92000: 3.397108
# Average loss at step 94000: 3.253331
# Average loss at step 96000: 3.356650
# Average loss at step 98000: 3.240095
# Average loss at step 100000: 3.352922
# Nearest to or: and, than, asynchronous, praising, like, advisory, groceries, while,
# Nearest to about: mingling, on, leopoldo, regarding, philippine, recurrence, frye, valdemar,
# Nearest to i: ii, we, you, iii, v, stoiber, t, mears,
# Nearest to up: off, out, back, them, him, down, apart, mendelevium,
# Nearest to often: usually, sometimes, commonly, generally, typically, still, now, frequently,
# Nearest to also: now, still, sometimes, often, never, actually, neurologist, which,
# Nearest to so: thus, how, too, then, say, hampered, sachsen, suggests,
# Nearest to is: was, has, became, becomes, are, be, does, seems,
# Nearest to war: wars, battle, hello, confound, assailants, bien, slanted, gulfs,
# Nearest to has: had, have, is, was, since, having, contains, ssris,
# Nearest to world: senior, serge, saeima, willys, indictments, sigmund, kinsella, expander,
# Nearest to he: she, it, they, there, who, we, never, mexicana,
# Nearest to a: the, another, any, reuse, scruggs, hypertension, counterproductive, defiance,
# Nearest to many: some, several, various, these, numerous, those, all, such,
# Nearest to two: four, three, five, six, seven, eight, one, nine,
# Nearest to all: various, several, any, many, these, every, both, some,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()


words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0


def generate_batch(batch_size, skip_window):
    global data_index
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    batch = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        labels[i, 0] = buffer[skip_window]
        batch[i, :] = list(buffer)[:skip_window] + \
            list(buffer)[(skip_window + 1):]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = {}:'.format(skip_window))
    for context, label in zip(batch, labels.ravel()):
        print('    context: [{context:30}] label: {label}'.format(
            context=', '.join(reverse_dictionary[word] for word in context),
            label=reverse_dictionary[label]))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     context: [anarchism, as                 ] label: originated
#     context: [originated, a                 ] label: as
#     context: [as, term                      ] label: a
#     context: [a, of                         ] label: term
#     context: [term, abuse                   ] label: of
#     context: [of, first                     ] label: abuse
#     context: [abuse, used                   ] label: first
#     context: [first, against                ] label: used
#
# with skip_window = 2:
#     context: [anarchism, originated, a, term] label: as
#     context: [originated, as, term, of      ] label: a
#     context: [as, a, of, abuse              ] label: term
#     context: [a, term, abuse, first         ] label: of
#     context: [term, of, first, used         ] label: abuse
#     context: [of, abuse, used, against      ] label: first
#     context: [abuse, first, against, early  ] label: used
#     context: [first, used, early, working   ] label: against

# %% [markdown]
# Train a CBOW model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default():

    # Input data.
    train_dataset = tf.placeholder(
        tf.int32, shape=[batch_size, 2 * skip_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    context = tf.reduce_mean(
        tf.nn.embedding_lookup(embeddings, train_dataset), axis=1)
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(
            weights=softmax_weights, biases=softmax_biases, inputs=context,
            labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001


with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000
            # batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500
        # steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.633057
# Nearest to have: conrad, shine, apostates, deontology, distributor, verify, subtended, immigrant,
# Nearest to american: joules, lawyer, implicate, bounce, fink, unionism, vindhya, donating,
# Nearest to was: bouncer, carelessness, nextstep, minstrels, curbed, metabolized, doctoral, troodos,
# Nearest to is: chokes, hipparchus, focal, vocabularies, pisa, galilee, correspond, afrobeat,
# Nearest to state: prs, bless, songbook, authorize, adherents, hessen, flugelhorn, floodplain,
# Nearest to the: nominate, doha, satrap, azrael, armour, nol, supernatural, ecole,
# Nearest to b: drinker, knights, colours, obsidian, musicals, tarentum, calvinists, babi,
# Nearest to it: dudley, associative, dodecanese, marquette, enrichment, hires, outcry, mag,
# Nearest to two: krishna, monarchy, coldest, booksellers, lut, methadone, philip, langue,
# Nearest to on: countrymen, accommodation, inconsistency, poetic, shevat, philippi, fantastic, sounded,
# Nearest to s: versions, epistemic, kullervo, terracotta, stockings, pci, kcal, carburetor,
# Nearest to i: understandable, eat, turnover, lots, superhuman, addons, tiamat, downwind,
# Nearest to its: leakage, doolittle, cardboard, sri, gigue, penguins, apartheid, indulgent,
# Nearest to he: ystem, irate, urraca, romanticized, conflicting, dagobert, dk, secretory,
# Nearest to one: delirium, lan, warned, technicolor, endeavors, timbres, mezzo, torque,
# Nearest to up: abrahamic, latent, dislikes, uniformed, alternation, storyline, treaty, dissenting,
# Average loss at step 2000: 4.032519
# Average loss at step 4000: 3.507950
# Average loss at step 6000: 3.338077
# Average loss at step 8000: 3.191584
# Average loss at step 10000: 3.143626
# Nearest to have: has, had, are, vertices, be, were, abugida, pater,
# Nearest to american: joules, fink, scotia, folkloric, plenipotentiary, mushrooms, subdominant, barrier,
# Nearest to was: is, had, were, has, been, troodos, be, putsch,
# Nearest to is: was, are, has, were, pidgin, twos, be, although,
# Nearest to state: prs, songbook, founder, floodplain, unleashing, descend, ploy, standardized,
# Nearest to the: its, their, his, a, this, caspar, phased, any,
# Nearest to b: d, bhaktivedanta, mcmanus, calvinists, knights, concerning, sands, drinker,
# Nearest to it: he, this, they, she, there, what, eph, navigated,
# Nearest to two: three, one, seven, six, four, eight, handlebar, five,
# Nearest to on: in, cays, through, adhesives, inconsistency, waldorf, accommodation, switch,
# Nearest to s: gbase, uneven, follicle, ts, minefields, sighted, epistemic, chrismation,
# Nearest to i: we, armand, qualitative, superhuman, understandable, turnover, montagu, downwind,
# Nearest to its: their, the, his, any, texan, suspending, nominate, minimalist,
# Nearest to he: she, it, they, who, interceptions, temporal, igbo, loew,
# Nearest to one: two, pedal, eight, nine, three, recent, triumvirate, byers,
# Nearest to up: latent, qdos, ploy, impose, seek, uniformed, convent, meridian,
# Average loss at step 12000: 3.169719
# Average loss at step 14000: 3.125469
# Average loss at step 16000: 3.151335
# Average loss at step 18000: 3.097648
# Average loss at step 20000: 2.994649
# Nearest to have: has, had, were, are, be, vertices, having, programme,
# Nearest to american: fink, joules, folkloric, british, independent, scotia, airplane, lawyer,
# Nearest to was: is, has, had, were, became, be, been, kids,
# Nearest to is: was, has, are, became, be, does, came, via,
# Nearest to state: floodplain, founder, bless, prs, macaulay, songbook, descend, tint,
# Nearest to the: a, their, its, his, sporting, any, this, pashtun,
# Nearest to b: d, drinker, calvinists, sands, mcmanus, bhaktivedanta, pronoun, knights,
# Nearest to it: he, she, this, there, they, what, navigated, loew,
# Nearest to two: three, six, seven, four, one, eight, handlebar, five,
# Nearest to on: in, through, upon, at, eidyn, exterminating, fabrication, basilisk,
# Nearest to s: gbase, his, ts, isbn, ziggy, follicle, uneven, eccentric,
# Nearest to i: we, you, montagu, qualitative, armand, tgv, superhuman, turnover,
# Nearest to its: their, his, the, any, our, her, texan, forma,
# Nearest to he: she, it, they, who, igbo, loew, there, interceptions,
# Nearest to one: two, eight, six, sided, seven, dawn, hrothgar, tessellations,
# Nearest to up: him, them, powered, casper, impose, latent, archangel, ploy,
# Average loss at step 22000: 3.049003
# Average loss at step 24000: 3.024514
# Average loss at step 26000: 2.991930
# Average loss at step 28000: 3.014164
# Average loss at step 30000: 2.988137
# Nearest to have: had, has, were, are, having, be, include, offseason,
# Nearest to american: fink, british, irish, joules, independent, airplane, table, scotia,
# Nearest to was: is, had, has, were, became, be, been, kids,
# Nearest to is: was, are, has, became, be, provides, does, seems,
# Nearest to state: floodplain, bless, macaulay, prs, founder, standardized, songbook, unleashing,
# Nearest to the: its, their, this, a, any, his, semen, phased,
# Nearest to b: d, drinker, pronoun, mcmanus, calvinists, sands, jumbo, solutes,
# Nearest to it: he, she, this, there, they, what, navigated, jerseys,
# Nearest to two: three, four, six, seven, five, eight, one, nine,
# Nearest to on: upon, in, through, waldorf, at, eidyn, exterminating, basilisk,
# Nearest to s: isbn, gbase, follicle, persistently, ludo, his, pups, chrismation,
# Nearest to i: we, you, turnover, armand, montagu, qualitative, haba, eat,
# Nearest to its: their, his, the, her, our, any, forma, bran,
# Nearest to he: she, it, they, who, never, interceptions, igbo, superlative,
# Nearest to one: two, five, four, dawn, six, sided, triumvirate, seven,
# Nearest to up: him, out, them, powered, back, casper, impose, qdos,
# Average loss at step 32000: 2.838098
# Average loss at step 34000: 2.946446
# Average loss at step 36000: 2.935314
# Average loss at step 38000: 2.938493
# Average loss at step 40000: 2.917916
# Nearest to have: had, has, were, are, having, be, provide, seem,
# Nearest to american: british, irish, fink, international, independent, skyway, airplane, canadian,
# Nearest to was: is, had, became, were, has, be, been, kids,
# Nearest to is: was, has, be, are, became, becomes, seems, correspond,
# Nearest to state: prs, founder, floodplain, bless, aford, extremists, city, pleads,
# Nearest to the: their, its, a, his, mandible, maher, arched, shir,
# Nearest to b: d, drinker, calvinists, unbounded, infrared, numbers, mcmanus, unaffected,
# Nearest to it: he, she, there, this, they, what, navigated, never,
# Nearest to two: three, six, four, five, seven, eight, one, nine,
# Nearest to on: upon, through, waldorf, eidyn, in, assembling, dfs, melodrama,
# Nearest to s: isbn, gbase, monotonicity, persistently, ludo, his, follicle, psychomotor,
# Nearest to i: we, you, turnover, haba, iii, UNK, pebbles, du,
# Nearest to its: their, his, the, her, our, forma, your, any,
# Nearest to he: she, it, they, there, who, igbo, interceptions, hardwood,
# Nearest to one: two, seven, excited, sided, six, eight, episcopate, maronite,
# Nearest to up: out, him, them, powered, off, casper, back, cardini,
# Average loss at step 42000: 2.941185
# Average loss at step 44000: 2.943359
# Average loss at step 46000: 2.904137
# Average loss at step 48000: 2.867817
# Average loss at step 50000: 2.845757
# Nearest to have: had, has, were, are, having, provide, include, require,
# Nearest to american: british, fink, irish, italian, canadian, german, joules, neuter,
# Nearest to was: is, became, had, were, has, been, be, kids,
# Nearest to is: was, has, are, be, became, refers, does, implies,
# Nearest to state: bless, floodplain, founder, flugelhorn, prs, ploy, city, pleads,
# Nearest to the: its, a, their, any, phased, loew, this, lori,
# Nearest to b: d, drinker, calvinists, mcmanus, bhaktivedanta, unbounded, sands, weldon,
# Nearest to it: he, she, there, this, they, never, loew, what,
# Nearest to two: three, four, six, seven, eight, five, nine, one,
# Nearest to on: upon, in, through, at, waldorf, melodrama, eidyn, against,
# Nearest to s: gbase, isbn, ts, his, follicle, ludo, monotonicity, tells,
# Nearest to i: we, you, turnover, haba, qualitative, iii, spears, hoisted,
# Nearest to its: their, his, the, her, our, your, whose, forma,
# Nearest to he: she, it, they, there, who, interceptions, probably, we,
# Nearest to one: four, two, seven, eight, nine, six, three, sided,
# Nearest to up: out, him, them, off, back, powered, casper, away,
# Average loss at step 52000: 2.883386
# Average loss at step 54000: 2.857651
# Average loss at step 56000: 2.855356
# Average loss at step 58000: 2.764617
# Average loss at step 60000: 2.833498
# Nearest to have: had, has, were, are, having, provide, require, seem,
# Nearest to american: british, irish, canadian, italian, german, fink, indian, international,
# Nearest to was: is, had, has, were, became, been, be, aconcagua,
# Nearest to is: was, has, are, be, seems, refers, becomes, appears,
# Nearest to state: ploy, bless, floodplain, founder, sedimentation, flugelhorn, macaulay, dwight,
# Nearest to the: its, their, his, our, this, your, shir, a,
# Nearest to b: d, drinker, unbounded, calvinists, weldon, c, bhaktivedanta, mcmanus,
# Nearest to it: he, she, there, this, they, itself, never, what,
# Nearest to two: three, four, six, five, one, seven, eight, nine,
# Nearest to on: upon, in, through, at, within, against, assembling, waldorf,
# Nearest to s: gbase, isbn, his, follicle, technological, ludo, mechanosynthesis, arthropod,
# Nearest to i: we, you, turnover, iii, haba, du, pebbles, t,
# Nearest to its: their, his, the, our, her, your, whose, noticeably,
# Nearest to he: she, it, they, who, there, we, despatch, probably,
# Nearest to one: two, seven, four, five, six, three, eight, nine,
# Nearest to up: out, off, him, them, back, powered, dusseldorf, away,
# Average loss at step 62000: 2.836668
# Average loss at step 64000: 2.779913
# Average loss at step 66000: 2.765722
# Average loss at step 68000: 2.717434
# Average loss at step 70000: 2.775821
# Nearest to have: had, has, are, were, having, be, require, seem,
# Nearest to american: british, canadian, irish, italian, german, fink, moroccan, australian,
# Nearest to was: is, became, had, were, has, be, been, kids,
# Nearest to is: was, has, be, are, became, seems, refers, remains,
# Nearest to state: ploy, macaulay, sedimentation, bless, founder, flugelhorn, pleads, unified,
# Nearest to the: its, their, a, phased, his, any, this, shir,
# Nearest to b: d, mcmanus, drinker, bhaktivedanta, calvinists, unbounded, weldon, slowdown,
# Nearest to it: he, she, there, they, this, itself, tighter, overgrown,
# Nearest to two: three, four, five, six, seven, eight, nine, one,
# Nearest to on: upon, in, through, at, within, assembling, eidyn, under,
# Nearest to s: isbn, gbase, ludo, his, follicle, burnley, technological, psychomotor,
# Nearest to i: we, you, iii, du, orphans, haba, turnover, superhuman,
# Nearest to its: their, his, the, her, our, your, whose, snk,
# Nearest to he: she, it, they, there, who, we, despatch, igbo,
# Nearest to one: seven, two, five, six, three, nine, four, expulsion,
# Nearest to up: off, out, him, them, back, away, dusseldorf, casper,
# Average loss at step 72000: 2.796783
# Average loss at step 74000: 2.655175
# Average loss at step 76000: 2.804250
# Average loss at step 78000: 2.821312
# Average loss at step 80000: 2.785930
# Nearest to have: had, has, were, are, having, seem, require, provide,
# Nearest to american: british, irish, italian, canadian, german, australian, french, indian,
# Nearest to was: is, has, had, were, became, be, been, newly,
# Nearest to is: was, has, becomes, are, remains, implies, seems, represents,
# Nearest to state: bless, founder, pleads, ploy, flugelhorn, hathor, states, macaulay,
# Nearest to the: its, their, shir, phased, a, arched, zooplankton, any,
# Nearest to b: d, drinker, unbounded, mcmanus, calvinists, slowdown, n, weldon,
# Nearest to it: he, she, there, this, they, itself, thus, postmillennialism,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to on: upon, in, through, around, regarding, waldorf, reuss, within,
# Nearest to s: isbn, gbase, whose, persistently, burnley, follicle, btu, ts,
# Nearest to i: we, you, iii, they, ii, du, orphans, pebbles,
# Nearest to its: their, his, the, her, our, whose, bard, snk,
# Nearest to he: she, it, they, who, there, despatch, hardwood, we,
# Nearest to one: two, three, seven, four, five, six, eight, nine,
# Nearest to up: off, out, him, back, them, away, down, dusseldorf,
# Average loss at step 82000: 2.673762
# Average loss at step 84000: 2.776937
# Average loss at step 86000: 2.745543
# Average loss at step 88000: 2.759133
# Average loss at step 90000: 2.741224
# Nearest to have: had, has, having, were, are, seem, require, receive,
# Nearest to american: irish, british, canadian, italian, french, indian, australian, international,
# Nearest to was: is, has, became, had, be, were, represents, putsch,
# Nearest to is: was, has, seems, refers, are, remains, becomes, appears,
# Nearest to state: city, bless, pleads, pattie, flugelhorn, founder, macaulay, ploy,
# Nearest to the: its, their, his, a, this, our, arched, any,
# Nearest to b: d, unbounded, drinker, c, n, calvinists, weldon, r,
# Nearest to it: he, she, there, this, they, itself, loew, quickly,
# Nearest to two: three, four, six, five, seven, eight, one, nine,
# Nearest to on: upon, in, regarding, through, assembling, waldorf, within, at,
# Nearest to s: isbn, follicle, ludo, whose, gbase, ts, nel, seclusion,
# Nearest to i: we, you, iii, they, ii, pebbles, orphans, mail,
# Nearest to its: their, his, the, her, our, whose, noticeably, your,
# Nearest to he: she, it, they, there, who, we, officially, probably,
# Nearest to one: two, six, eight, four, seven, nine, three, five,
# Nearest to up: off, out, him, them, back, down, dusseldorf, away,
# Average loss at step 92000: 2.690862
# Average loss at step 94000: 2.726327
# Average loss at step 96000: 2.714176
# Average loss at step 98000: 2.380835
# Average loss at step 100000: 2.426578
# Nearest to have: had, has, having, are, were, include, require, seem,
# Nearest to american: british, canadian, italian, english, irish, german, fink, french,
# Nearest to was: is, became, were, had, be, has, been, putsch,
# Nearest to is: was, has, became, seems, are, be, appears, represents,
# Nearest to state: states, flugelhorn, city, harvard, dwight, pattie, macaulay, founder,
# Nearest to the: his, its, their, our, arched, shir, your, phased,
# Nearest to b: d, di, bhaktivedanta, slowdown, lice, mcmanus, rabinowitz, cory,
# Nearest to it: he, she, there, this, they, itself, never, nothing,
# Nearest to two: three, four, five, six, seven, eight, nine, zero,
# Nearest to on: upon, through, at, waldorf, regarding, in, palomino, eidyn,
# Nearest to s: isbn, persistently, follicle, gbase, burnley, mechanosynthesis, whose, liturgies,
# Nearest to i: we, you, iii, ii, they, pebbles, spears, undersea,
# Nearest to its: their, his, her, the, whose, our, your, anesthetic,
# Nearest to he: she, they, it, there, who, we, never, officially,
# Nearest to one: two, resulting, triumvirate, seven, bonaventure, besiege, three, checkers,
# Nearest to up: off, out, him, them, back, together, down, dusseldorf,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()


words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
